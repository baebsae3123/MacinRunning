# %% [markdown]
# <a href="https://colab.research.google.com/github/baebsae3123/MacinRunning/blob/main/%EB%AA%A8%EB%8D%B8_%EC%84%B1%EB%8A%A5_%ED%8F%89%EA%B0%80_%EB%B9%84%EA%B5%90_%EA%B7%B8%EB%9E%98%ED%94%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## RandomForestRegressor / XGBRegressor / KMeans  써보기

# %% [markdown]
# ✅ 📈 4. 성능 비교 방법
#
# 👉 이게 제일 중요
#
# ✔ 정확도 (Accuracy)
# 맞춘 비율
# ✔ 정밀도 (Precision)
# “여드름 있다고 했는데 진짜 맞냐”
# ✔ 재현율 (Recall)
# “실제 여드름을 얼마나 잘 잡았냐”
